# %%
# %matplotlib inline

# %%
from lxml import etree
from io import StringIO
from collections import defaultdict
import csv
import pubchempy as pcp
import sys

is_python3 = sys.version_info.major == 3
if is_python3:
    unicode = str

# Parse XML
data = open("../Data/DrugBank_Full_DB.xml","r")
xml_content = data.read().encode()
root = etree.XML(xml_content)

print(len(root),'drugs')
# Out:
# 13475 drugs

# %% [markdown]
# ## Iterate over drugs

# %%
drug2attrib = defaultdict(dict)
# drugbank_id -> {'drugname', 'drug_type', 'groups', 'targets/enzymes/transporters': [_id, _actions]}

target2attrib = defaultdict(dict)
enzyme2attrib = defaultdict(dict)
transporter2attrib = defaultdict(dict)
# drugbank_target_id -> {'gene', 'name', 'organism', 'taxonomy_id', 'uniprot_id', 'genbank_gene_id', 'genbank_protein_id', 'hgnc_id'}

tag_prefix = '{http://www.drugbank.ca}'

for child in root:
    for s in child.findall(tag_prefix+'drugbank-id'):
        if 'primary' in s.attrib:
            drugbank_id = s.text

    drugname = child.findall(tag_prefix+'name')[0].text
    drug2attrib[drugbank_id]['drugname'] = drugname

    #results = pcp.get_compounds(drugname.split(" ")[0], 'name')
    #if (len(results)>0):
    #    smiles = results[0].isomeric_smiles
    #    drug2attrib[drugbank_id]['SMILES'] = smiles
    #else:
    #    smiles = ""
    #    drug2attrib[drugbank_id]['SMILES'] = smiles
    
    drug_type = child.attrib['type']
    drug2attrib[drugbank_id]['drug_type'] = drug_type

    groups = [s.text for s in child.find(tag_prefix+'groups').findall(tag_prefix+'group')]
    drug2attrib[drugbank_id]['groups'] = groups

    # Get targets
    drug2attrib[drugbank_id]['targets'] = []
    for target in child.find(tag_prefix+'targets').findall(tag_prefix+'target'):
        if target.find(tag_prefix+'polypeptide') is None:
            continue
        
        target_id = target.find(tag_prefix+'id').text
        target_gene = target.find(tag_prefix+'polypeptide').find(tag_prefix+'gene-name').text
        target_name = target.find(tag_prefix+'name').text
        target_organism = target.find(tag_prefix+'organism').text
        target_taxonomy_id = target.find(tag_prefix+'polypeptide').find(tag_prefix+'organism').attrib['ncbi-taxonomy-id']
        
        if target_organism is None and target_taxonomy_id == '9606':
            target_organism = 'Human'
        if target_organism == 'Human' and target_taxonomy_id == '':
            target_taxonomy_id = '9606'
        if target_organism == 'Homo sapiens':
            target_organism = 'Human'
        if target_gene is None or target_organism is None or target_taxonomy_id is None:
            continue
        
        target_external_ids = target.find(tag_prefix+'polypeptide').find(tag_prefix+'external-identifiers').findall(tag_prefix+'external-identifier')
        target_uniprot_id = ''
        target_genbank_gene = ''
        target_genbank_protein = ''
        target_hgnc_id = ''

        for external_id in target_external_ids:
            if external_id.find(tag_prefix+'resource').text == 'UniProtKB':
                target_uniprot_id = external_id.find(tag_prefix+'identifier').text
            elif external_id.find(tag_prefix+'resource').text == 'GenBank Gene Database':
                target_genbank_gene = external_id.find(tag_prefix+'identifier').text
            elif external_id.find(tag_prefix+'resource').text == 'GenBank Protein Database':
                target_genbank_protein = external_id.find(tag_prefix+'identifier').text
            elif external_id.find(tag_prefix+'resource').text == 'HUGO Gene Nomenclature Committee (HGNC)':
                target_hgnc_id = external_id.find(tag_prefix+'identifier').text

        target_actions = [s.text.lower() for s in target.find(tag_prefix+'actions').findall(tag_prefix+'action')]
        
        drug2attrib[drugbank_id]['targets'].append((target_id,target_actions))

        if target_id not in target2attrib: #{'gene', 'name', 'organism', 'taxonomy_id', 'uniprot_id', 'genbank_gene_id', 'genbank_protein_id', 'hgnc_id'}
            target2attrib[target_id]['gene'] = target_gene
            target2attrib[target_id]['name'] = target_name
            target2attrib[target_id]['organism'] = target_organism
            target2attrib[target_id]['taxonomy_id'] = target_taxonomy_id
            
            target2attrib[target_id]['uniprot_id'] = target_uniprot_id
            target2attrib[target_id]['genbank_gene_id'] = target_genbank_gene
            target2attrib[target_id]['genbank_protein_id'] = target_genbank_protein
            target2attrib[target_id]['hgnc_id'] = target_hgnc_id

        #print target_id, target_gene, target_name, target_organism, target_taxonomy_id, target_actions


    # Get enzymes
    drug2attrib[drugbank_id]['enzymes'] = []
    for enzyme in child.find(tag_prefix+'enzymes').findall(tag_prefix+'enzyme'):
        if enzyme.find(tag_prefix+'polypeptide') is None:
            continue
        
        enzyme_id = enzyme.find(tag_prefix+'id').text
        enzyme_gene = enzyme.find(tag_prefix+'polypeptide').find(tag_prefix+'gene-name').text
        enzyme_name = enzyme.find(tag_prefix+'name').text
        enzyme_organism = enzyme.find(tag_prefix+'organism').text
        enzyme_taxonomy_id = enzyme.find(tag_prefix+'polypeptide').find(tag_prefix+'organism').attrib['ncbi-taxonomy-id']
        
        if enzyme_organism is None and enzyme_taxonomy_id == '9606':
            enzyme_organism = 'Human'
        if enzyme_organism == 'Human' and enzyme_taxonomy_id == '':
            enzyme_taxonomy_id = '9606'
        if enzyme_organism == 'Homo sapiens':
            enzyme_organism = 'Human'
        if enzyme_gene is None or enzyme_organism is None or enzyme_taxonomy_id is None:
            continue
        
        enzyme_external_ids = enzyme.find(tag_prefix+'polypeptide').find(tag_prefix+'external-identifiers').findall(tag_prefix+'external-identifier')
        enzyme_uniprot_id = ''
        enzyme_genbank_gene = ''
        enzyme_genbank_protein = ''
        enzyme_hgnc_id = ''

        for external_id in enzyme_external_ids:
            if external_id.find(tag_prefix+'resource').text == 'UniProtKB':
                enzyme_uniprot_id = external_id.find(tag_prefix+'identifier').text
            elif external_id.find(tag_prefix+'resource').text == 'GenBank Gene Database':
                enzyme_genbank_gene = external_id.find(tag_prefix+'identifier').text
            elif external_id.find(tag_prefix+'resource').text == 'GenBank Protein Database':
                enzyme_genbank_protein = external_id.find(tag_prefix+'identifier').text
            elif external_id.find(tag_prefix+'resource').text == 'HUGO Gene Nomenclature Committee (HGNC)':
                enzyme_hgnc_id = external_id.find(tag_prefix+'identifier').text

        enzyme_actions = [s.text.lower() for s in enzyme.find(tag_prefix+'actions').findall(tag_prefix+'action')]
        
        drug2attrib[drugbank_id]['enzymes'].append((enzyme_id,enzyme_actions))

        if enzyme_id not in enzyme2attrib: #{'gene', 'name', 'organism', 'taxonomy_id', 'uniprot_id', 'genbank_gene_id', 'genbank_protein_id', 'hgnc_id'}
            enzyme2attrib[enzyme_id]['gene'] = enzyme_gene
            enzyme2attrib[enzyme_id]['name'] = enzyme_name
            enzyme2attrib[enzyme_id]['organism'] = enzyme_organism
            enzyme2attrib[enzyme_id]['taxonomy_id'] = enzyme_taxonomy_id
            
            enzyme2attrib[enzyme_id]['uniprot_id'] = enzyme_uniprot_id
            enzyme2attrib[enzyme_id]['genbank_gene_id'] = enzyme_genbank_gene
            enzyme2attrib[enzyme_id]['genbank_protein_id'] = enzyme_genbank_protein
            enzyme2attrib[enzyme_id]['hgnc_id'] = enzyme_hgnc_id

        #print enzyme_id, enzyme_gene, enzyme_name, enzyme_organism, enzyme_taxonomy_id, enzyme_actions


    # Get transporters
    drug2attrib[drugbank_id]['transporters'] = []
    for transporter in child.find(tag_prefix+'transporters').findall(tag_prefix+'transporter'):
        if transporter.find(tag_prefix+'polypeptide') is None:
            continue
        
        transporter_id = transporter.find(tag_prefix+'id').text
        transporter_gene = transporter.find(tag_prefix+'polypeptide').find(tag_prefix+'gene-name').text
        transporter_name = transporter.find(tag_prefix+'name').text
        transporter_organism = transporter.find(tag_prefix+'organism').text
        transporter_taxonomy_id = transporter.find(tag_prefix+'polypeptide').find(tag_prefix+'organism').attrib['ncbi-taxonomy-id']
        
        if transporter_organism is None and transporter_taxonomy_id == '9606':
            transporter_organism = 'Human'
        if transporter_organism == 'Human' and transporter_taxonomy_id == '':
            transporter_taxonomy_id = '9606'
        if transporter_organism == 'Homo sapiens':
            transporter_organism = 'Human'
        if transporter_gene is None or transporter_organism is None or transporter_taxonomy_id is None:
            continue
        
        transporter_external_ids = transporter.find(tag_prefix+'polypeptide').find(tag_prefix+'external-identifiers').findall(tag_prefix+'external-identifier')
        transporter_uniprot_id = ''
        transporter_genbank_gene = ''
        transporter_genbank_protein = ''
        transporter_hgnc_id = ''

        for external_id in transporter_external_ids:
            if external_id.find(tag_prefix+'resource').text == 'UniProtKB':
                transporter_uniprot_id = external_id.find(tag_prefix+'identifier').text
            elif external_id.find(tag_prefix+'resource').text == 'GenBank Gene Database':
                transporter_genbank_gene = external_id.find(tag_prefix+'identifier').text
            elif external_id.find(tag_prefix+'resource').text == 'GenBank Protein Database':
                transporter_genbank_protein = external_id.find(tag_prefix+'identifier').text
            elif external_id.find(tag_prefix+'resource').text == 'HUGO Gene Nomenclature Committee (HGNC)':
                transporter_hgnc_id = external_id.find(tag_prefix+'identifier').text

        transporter_actions = [s.text.lower() for s in transporter.find(tag_prefix+'actions').findall(tag_prefix+'action')]
        
        drug2attrib[drugbank_id]['transporters'].append((transporter_id,transporter_actions))

        if transporter_id not in transporter2attrib: #{'gene', 'name', 'organism', 'taxonomy_id', 'uniprot_id', 'genbank_gene_id', 'genbank_protein_id', 'hgnc_id'}
            transporter2attrib[transporter_id]['gene'] = transporter_gene
            transporter2attrib[transporter_id]['name'] = transporter_name
            transporter2attrib[transporter_id]['organism'] = transporter_organism
            transporter2attrib[transporter_id]['taxonomy_id'] = transporter_taxonomy_id
            
            transporter2attrib[transporter_id]['uniprot_id'] = transporter_uniprot_id
            transporter2attrib[transporter_id]['genbank_gene_id'] = transporter_genbank_gene
            transporter2attrib[transporter_id]['genbank_protein_id'] = transporter_genbank_protein
            transporter2attrib[transporter_id]['hgnc_id'] = transporter_hgnc_id

        #print transporter_id, transporter_gene, transporter_name, transporter_organism, transporter_taxonomy_id, transporter_actions


    print(drugbank_id, drugname, drug_type, groups,
         'targets:', len(drug2attrib[drugbank_id]['targets']),
         'enzymes:', len(drug2attrib[drugbank_id]['enzymes']),
         'transporters:', len(drug2attrib[drugbank_id]['transporters']))
#    print('\n')
# Out:
# DB00001 Lepirudin biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00002 Cetuximab biotech ['approved'] targets: 12 enzymes: 0 transporters: 0
# DB00003 Dornase alfa biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00004 Denileukin diftitox biotech ['approved', 'investigational'] targets: 3 enzymes: 0 transporters: 0
# DB00005 Etanercept biotech ['approved', 'investigational'] targets: 14 enzymes: 0 transporters: 0
# DB00006 Bivalirudin small molecule ['approved', 'investigational'] targets: 1 enzymes: 1 transporters: 0
# DB00007 Leuprolide small molecule ['approved', 'investigational'] targets: 1 enzymes: 1 transporters: 0
# DB00008 Peginterferon alfa-2a biotech ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00009 Alteplase biotech ['approved'] targets: 4 enzymes: 0 transporters: 0
# DB00010 Sermorelin biotech ['approved', 'withdrawn'] targets: 1 enzymes: 0 transporters: 0
# DB00011 Interferon alfa-n1 biotech ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00012 Darbepoetin alfa biotech ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00013 Urokinase biotech ['approved', 'investigational', 'withdrawn'] targets: 10 enzymes: 0 transporters: 0
# DB00014 Goserelin small molecule ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00015 Reteplase biotech ['approved', 'investigational'] targets: 4 enzymes: 0 transporters: 0
# DB00016 Erythropoietin biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00017 Salmon Calcitonin biotech ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00018 Interferon alfa-n3 biotech ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00019 Pegfilgrastim biotech ['approved'] targets: 1 enzymes: 1 transporters: 0
# DB00020 Sargramostim biotech ['approved', 'investigational'] targets: 5 enzymes: 0 transporters: 0
# DB00022 Peginterferon alfa-2b biotech ['approved'] targets: 2 enzymes: 3 transporters: 0
# DB00023 Asparaginase Escherichia coli biotech ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00024 Thyrotropin alfa biotech ['approved', 'vet_approved'] targets: 1 enzymes: 0 transporters: 0
# DB00025 Antihemophilic factor, human recombinant biotech ['approved', 'investigational'] targets: 11 enzymes: 2 transporters: 0
# DB00026 Anakinra biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00027 Gramicidin D small molecule ['approved'] targets: 0 enzymes: 0 transporters: 1
# DB00028 Human immunoglobulin G biotech ['approved', 'investigational'] targets: 11 enzymes: 0 transporters: 0
# DB00029 Anistreplase biotech ['approved'] targets: 4 enzymes: 0 transporters: 0
# DB00030 Insulin human biotech ['approved', 'investigational'] targets: 4 enzymes: 4 transporters: 0
# DB00031 Tenecteplase biotech ['approved'] targets: 11 enzymes: 0 transporters: 0
# DB00032 Menotropins biotech ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00033 Interferon gamma-1b biotech ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00034 Interferon alfa-2a, Recombinant biotech ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00035 Desmopressin small molecule ['approved'] targets: 3 enzymes: 2 transporters: 0
# DB00036 Coagulation factor VIIa Recombinant Human biotech ['approved'] targets: 6 enzymes: 0 transporters: 0
# DB00038 Oprelvekin biotech ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00039 Palifermin biotech ['approved'] targets: 6 enzymes: 0 transporters: 0
# DB00040 Glucagon biotech ['approved'] targets: 3 enzymes: 0 transporters: 0
# DB00041 Aldesleukin biotech ['approved'] targets: 3 enzymes: 5 transporters: 0
# DB00042 Botulinum Toxin Type B biotech ['approved', 'investigational'] targets: 3 enzymes: 0 transporters: 0
# DB00043 Omalizumab biotech ['approved', 'investigational'] targets: 2 enzymes: 0 transporters: 0
# DB00044 Lutropin alfa biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00045 Lyme disease vaccine (recombinant OspA) biotech ['approved', 'withdrawn'] targets: 1 enzymes: 0 transporters: 0
# DB00046 Insulin lispro biotech ['approved'] targets: 2 enzymes: 1 transporters: 0
# DB00047 Insulin glargine biotech ['approved'] targets: 2 enzymes: 1 transporters: 0
# DB00048 Collagenase clostridium histolyticum biotech ['approved', 'investigational'] targets: 4 enzymes: 0 transporters: 0
# DB00049 Rasburicase biotech ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00050 Cetrorelix small molecule ['approved', 'investigational'] targets: 2 enzymes: 0 transporters: 0
# DB00051 Adalimumab biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00052 Somatotropin biotech ['approved', 'investigational'] targets: 2 enzymes: 0 transporters: 0
# DB00053 Imiglucerase biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00054 Abciximab biotech ['approved'] targets: 14 enzymes: 0 transporters: 0
# DB00055 Drotrecogin alfa biotech ['approved', 'investigational', 'withdrawn'] targets: 12 enzymes: 0 transporters: 0
# DB00056 Gemtuzumab ozogamicin biotech ['approved', 'investigational'] targets: 12 enzymes: 0 transporters: 0
# DB00057 Indium In-111 satumomab pendetide biotech ['experimental', 'withdrawn'] targets: 0 enzymes: 0 transporters: 0
# DB00058 Alpha-1-proteinase inhibitor biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00059 Pegaspargase biotech ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00060 Interferon beta-1a biotech ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00061 Pegademase biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00062 Albumin human biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00063 Eptifibatide biotech ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00065 Infliximab biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00066 Follitropin biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00067 Vasopressin small molecule ['approved'] targets: 3 enzymes: 0 transporters: 1
# DB00068 Interferon beta-1b biotech ['approved'] targets: 2 enzymes: 1 transporters: 0
# DB00069 Interferon alfacon-1 biotech ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00070 Hyaluronidase (ovine) biotech ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00071 Insulin pork biotech ['approved'] targets: 14 enzymes: 1 transporters: 0
# DB00072 Trastuzumab biotech ['approved', 'investigational'] targets: 13 enzymes: 0 transporters: 0
# DB00073 Rituximab biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00074 Basiliximab biotech ['approved', 'investigational'] targets: 13 enzymes: 0 transporters: 0
# DB00075 Muromonab biotech ['approved', 'investigational'] targets: 15 enzymes: 0 transporters: 0
# DB00076 Digoxin Immune Fab (Ovine) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00078 Ibritumomab tiuxetan biotech ['approved', 'investigational'] targets: 12 enzymes: 0 transporters: 0
# DB00080 Daptomycin small molecule ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00081 Tositumomab biotech ['approved', 'investigational'] targets: 11 enzymes: 0 transporters: 0
# DB00082 Pegvisomant biotech ['approved'] targets: 1 enzymes: 6 transporters: 0
# DB00083 Botulinum toxin type A biotech ['approved', 'investigational'] targets: 2 enzymes: 0 transporters: 0
# DB00085 Pancrelipase biotech ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00086 Streptokinase biotech ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00087 Alemtuzumab biotech ['approved', 'investigational'] targets: 11 enzymes: 0 transporters: 0
# DB00088 Alglucerase biotech ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00089 Capromab pendetide biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00090 Laronidase biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00091 Cyclosporine small molecule ['approved', 'investigational', 'vet_approved'] targets: 4 enzymes: 6 transporters: 12
# DB00092 Alefacept biotech ['approved', 'investigational', 'withdrawn'] targets: 11 enzymes: 0 transporters: 0
# DB00093 Felypressin small molecule ['experimental'] targets: 1 enzymes: 0 transporters: 0
# DB00094 Urofollitropin biotech ['approved', 'vet_approved'] targets: 1 enzymes: 0 transporters: 0
# DB00095 Efalizumab biotech ['approved', 'investigational'] targets: 11 enzymes: 0 transporters: 0
# DB00097 Choriogonadotropin alfa biotech ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00098 Antithymocyte immunoglobulin (rabbit) biotech ['approved'] targets: 9 enzymes: 0 transporters: 0
# DB00099 Filgrastim biotech ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00100 Coagulation Factor IX (Recombinant) biotech ['approved', 'investigational'] targets: 7 enzymes: 0 transporters: 0
# DB00102 Becaplermin biotech ['approved', 'investigational'] targets: 3 enzymes: 0 transporters: 0
# DB00103 Agalsidase beta biotech ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00104 Octreotide small molecule ['approved', 'investigational'] targets: 3 enzymes: 2 transporters: 0
# DB00105 Interferon alfa-2b biotech ['approved'] targets: 2 enzymes: 1 transporters: 0
# DB00106 Abarelix small molecule ['approved', 'investigational', 'withdrawn'] targets: 1 enzymes: 0 transporters: 0
# DB00107 Oxytocin biotech ['approved', 'vet_approved'] targets: 2 enzymes: 1 transporters: 0
# DB00108 Natalizumab biotech ['approved', 'investigational'] targets: 12 enzymes: 0 transporters: 0
# DB00109 Enfuvirtide biotech ['approved', 'investigational'] targets: 1 enzymes: 2 transporters: 0
# DB00110 Palivizumab biotech ['approved', 'investigational'] targets: 11 enzymes: 0 transporters: 0
# DB00111 Daclizumab biotech ['investigational', 'withdrawn'] targets: 12 enzymes: 0 transporters: 0
# DB00112 Bevacizumab biotech ['approved', 'investigational'] targets: 11 enzymes: 0 transporters: 0
# DB00113 Technetium Tc-99m arcitumomab biotech ['experimental'] targets: 1 enzymes: 0 transporters: 0
# DB00114 Pyridoxal phosphate small molecule ['approved', 'investigational', 'nutraceutical'] targets: 60 enzymes: 0 transporters: 0
# DB00115 Cyanocobalamin small molecule ['approved', 'nutraceutical'] targets: 6 enzymes: 2 transporters: 7
# DB00116 Tetrahydrofolic acid small molecule ['nutraceutical'] targets: 11 enzymes: 0 transporters: 1
# DB00117 Histidine small molecule ['investigational', 'nutraceutical'] targets: 4 enzymes: 0 transporters: 1
# DB00118 Ademetionine small molecule ['approved', 'investigational', 'nutraceutical'] targets: 8 enzymes: 2 transporters: 0
# DB00119 Pyruvic acid small molecule ['approved', 'investigational', 'nutraceutical'] targets: 14 enzymes: 0 transporters: 5
# DB00120 Phenylalanine small molecule ['approved', 'investigational', 'nutraceutical'] targets: 7 enzymes: 0 transporters: 1
# DB00121 Biotin small molecule ['approved', 'investigational', 'nutraceutical'] targets: 9 enzymes: 1 transporters: 0
# DB00122 Choline small molecule ['approved', 'nutraceutical'] targets: 8 enzymes: 5 transporters: 10
# DB00123 L-Lysine small molecule ['approved', 'nutraceutical'] targets: 5 enzymes: 0 transporters: 2
# DB00125 Arginine small molecule ['investigational', 'nutraceutical'] targets: 9 enzymes: 0 transporters: 3
# DB00126 Ascorbic acid small molecule ['approved', 'nutraceutical'] targets: 24 enzymes: 0 transporters: 1
# DB00127 Spermine small molecule ['experimental', 'nutraceutical'] targets: 6 enzymes: 3 transporters: 2
# DB00128 Aspartic acid small molecule ['approved', 'nutraceutical'] targets: 22 enzymes: 0 transporters: 1
# DB00129 Ornithine small molecule ['approved', 'nutraceutical'] targets: 14 enzymes: 0 transporters: 0
# DB00130 L-Glutamine small molecule ['approved', 'investigational', 'nutraceutical'] targets: 3 enzymes: 19 transporters: 4
# DB00131 Adenosine phosphate small molecule ['approved', 'investigational', 'nutraceutical'] targets: 15 enzymes: 2 transporters: 0
# DB00132 alpha-Linolenic acid small molecule ['approved', 'investigational', 'nutraceutical'] targets: 10 enzymes: 0 transporters: 0
# DB00133 Serine small molecule ['investigational', 'nutraceutical'] targets: 7 enzymes: 0 transporters: 1
# DB00134 Methionine small molecule ['approved', 'nutraceutical'] targets: 5 enzymes: 10 transporters: 1
# DB00135 Tyrosine small molecule ['approved', 'investigational', 'nutraceutical'] targets: 4 enzymes: 0 transporters: 2
# DB00136 Calcitriol small molecule ['approved', 'nutraceutical'] targets: 2 enzymes: 2 transporters: 0
# DB00137 Lutein small molecule ['approved', 'investigational', 'nutraceutical'] targets: 0 enzymes: 0 transporters: 0
# DB00138 Cystine small molecule ['approved', 'nutraceutical'] targets: 4 enzymes: 0 transporters: 1
# DB00139 Succinic acid small molecule ['approved', 'nutraceutical'] targets: 26 enzymes: 0 transporters: 1
# DB00140 Riboflavin small molecule ['approved', 'investigational', 'nutraceutical', 'vet_approved'] targets: 3 enzymes: 2 transporters: 1
# DB00141 N-Acetylglucosamine small molecule ['approved', 'investigational', 'nutraceutical'] targets: 8 enzymes: 0 transporters: 0
# DB00142 Glutamic acid small molecule ['approved', 'nutraceutical'] targets: 70 enzymes: 0 transporters: 2
# DB00143 Glutathione small molecule ['approved', 'investigational', 'nutraceutical'] targets: 42 enzymes: 2 transporters: 5
# DB00144 Phosphatidyl serine small molecule ['approved', 'investigational', 'nutraceutical'] targets: 10 enzymes: 0 transporters: 0
# DB00145 Glycine small molecule ['approved', 'nutraceutical', 'vet_approved'] targets: 30 enzymes: 0 transporters: 1
# DB00146 Calcifediol small molecule ['approved', 'nutraceutical'] targets: 1 enzymes: 2 transporters: 0
# DB00147 Pyridoxal small molecule ['experimental', 'nutraceutical'] targets: 1 enzymes: 0 transporters: 0
# DB00148 Creatine small molecule ['approved', 'investigational', 'nutraceutical'] targets: 6 enzymes: 0 transporters: 1
# DB00149 Leucine small molecule ['investigational', 'nutraceutical'] targets: 6 enzymes: 0 transporters: 2
# DB00150 Tryptophan small molecule ['approved', 'nutraceutical', 'withdrawn'] targets: 3 enzymes: 8 transporters: 2
# DB00151 Cysteine small molecule ['approved', 'nutraceutical'] targets: 13 enzymes: 0 transporters: 1
# DB00152 Thiamine small molecule ['approved', 'investigational', 'nutraceutical', 'vet_approved'] targets: 2 enzymes: 1 transporters: 3
# DB00153 Ergocalciferol small molecule ['approved', 'nutraceutical'] targets: 2 enzymes: 6 transporters: 0
# DB00154 Dihomo-gamma-linolenic acid small molecule ['investigational', 'nutraceutical'] targets: 2 enzymes: 0 transporters: 0
# DB00155 Citrulline small molecule ['approved', 'investigational', 'nutraceutical'] targets: 13 enzymes: 0 transporters: 1
# DB00156 Threonine small molecule ['approved', 'nutraceutical'] targets: 3 enzymes: 0 transporters: 1
# DB00157 NADH small molecule ['approved', 'nutraceutical'] targets: 144 enzymes: 9 transporters: 0
# DB00158 Folic acid small molecule ['approved', 'nutraceutical', 'vet_approved'] targets: 3 enzymes: 3 transporters: 7
# DB00159 Icosapent small molecule ['approved', 'nutraceutical'] targets: 11 enzymes: 0 transporters: 0
# DB00160 Alanine small molecule ['nutraceutical'] targets: 13 enzymes: 0 transporters: 1
# DB00161 Valine small molecule ['approved', 'nutraceutical'] targets: 3 enzymes: 3 transporters: 1
# DB00162 Vitamin A small molecule ['approved', 'nutraceutical', 'vet_approved'] targets: 18 enzymes: 1 transporters: 0
# DB00163 Vitamin E small molecule ['approved', 'nutraceutical', 'vet_approved'] targets: 10 enzymes: 9 transporters: 4
# DB00165 Pyridoxine small molecule ['approved', 'investigational', 'nutraceutical', 'vet_approved'] targets: 1 enzymes: 1 transporters: 0
# DB00166 Lipoic acid small molecule ['approved', 'investigational', 'nutraceutical'] targets: 3 enzymes: 1 transporters: 0
# DB00167 Isoleucine small molecule ['investigational', 'nutraceutical'] targets: 5 enzymes: 0 transporters: 1
# DB00168 Aspartame small molecule ['investigational', 'nutraceutical'] targets: 3 enzymes: 0 transporters: 3
# DB00169 Cholecalciferol small molecule ['approved', 'nutraceutical'] targets: 1 enzymes: 7 transporters: 0
# DB00170 Menadione small molecule ['approved', 'nutraceutical'] targets: 13 enzymes: 6 transporters: 0
# DB00171 ATP small molecule ['investigational', 'nutraceutical'] targets: 42 enzymes: 1 transporters: 0
# DB00172 Proline small molecule ['nutraceutical'] targets: 22 enzymes: 1 transporters: 1
# DB00173 Adenine small molecule ['approved', 'nutraceutical'] targets: 11 enzymes: 1 transporters: 0
# DB00174 Asparagine small molecule ['approved', 'investigational', 'nutraceutical'] targets: 6 enzymes: 0 transporters: 1
# DB00175 Pravastatin small molecule ['approved'] targets: 2 enzymes: 0 transporters: 13
# DB00176 Fluvoxamine small molecule ['approved', 'investigational'] targets: 2 enzymes: 8 transporters: 2
# DB00177 Valsartan small molecule ['approved', 'investigational'] targets: 1 enzymes: 1 transporters: 3
# DB00178 Ramipril small molecule ['approved'] targets: 2 enzymes: 1 transporters: 2
# DB00179 Masoprocol small molecule ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00180 Flunisolide small molecule ['approved', 'investigational'] targets: 1 enzymes: 1 transporters: 0
# DB00181 Baclofen small molecule ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00182 Amphetamine small molecule ['approved', 'illicit', 'investigational'] targets: 12 enzymes: 2 transporters: 2
# DB00183 Pentagastrin small molecule ['approved'] targets: 1 enzymes: 1 transporters: 0
# DB00184 Nicotine small molecule ['approved'] targets: 13 enzymes: 13 transporters: 5
# DB00185 Cevimeline small molecule ['approved'] targets: 2 enzymes: 3 transporters: 0
# DB00186 Lorazepam small molecule ['approved'] targets: 2 enzymes: 2 transporters: 0
# DB00187 Esmolol small molecule ['approved'] targets: 1 enzymes: 1 transporters: 0
# DB00188 Bortezomib small molecule ['approved', 'investigational'] targets: 2 enzymes: 5 transporters: 0
# DB00189 Ethchlorvynol small molecule ['approved', 'illicit', 'withdrawn'] targets: 1 enzymes: 0 transporters: 0
# DB00190 Carbidopa small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00191 Phentermine small molecule ['approved', 'illicit'] targets: 6 enzymes: 1 transporters: 0
# DB00192 Indecainide small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00193 Tramadol small molecule ['approved', 'investigational'] targets: 15 enzymes: 4 transporters: 1
# DB00194 Vidarabine small molecule ['approved', 'investigational'] targets: 1 enzymes: 1 transporters: 0
# DB00195 Betaxolol small molecule ['approved', 'investigational'] targets: 2 enzymes: 2 transporters: 0
# DB00196 Fluconazole small molecule ['approved', 'investigational'] targets: 1 enzymes: 4 transporters: 1
# DB00197 Troglitazone small molecule ['approved', 'investigational', 'withdrawn'] targets: 9 enzymes: 19 transporters: 2
# DB00198 Oseltamivir small molecule ['approved'] targets: 3 enzymes: 1 transporters: 3
# DB00199 Erythromycin small molecule ['approved', 'investigational', 'vet_approved'] targets: 2 enzymes: 3 transporters: 6
# DB00200 Hydroxocobalamin small molecule ['approved'] targets: 9 enzymes: 0 transporters: 0
# DB00201 Caffeine small molecule ['approved'] targets: 14 enzymes: 8 transporters: 1
# DB00202 Succinylcholine small molecule ['approved'] targets: 5 enzymes: 1 transporters: 0
# DB00203 Sildenafil small molecule ['approved', 'investigational'] targets: 3 enzymes: 7 transporters: 5
# DB00204 Dofetilide small molecule ['approved', 'investigational'] targets: 3 enzymes: 1 transporters: 1
# DB00205 Pyrimethamine small molecule ['approved', 'investigational', 'vet_approved'] targets: 2 enzymes: 1 transporters: 2
# DB00206 Reserpine small molecule ['approved', 'investigational'] targets: 3 enzymes: 1 transporters: 7
# DB00207 Azithromycin small molecule ['approved'] targets: 1 enzymes: 1 transporters: 2
# DB00208 Ticlopidine small molecule ['approved'] targets: 1 enzymes: 8 transporters: 0
# DB00209 Trospium small molecule ['approved'] targets: 1 enzymes: 1 transporters: 0
# DB00210 Adapalene small molecule ['approved'] targets: 7 enzymes: 0 transporters: 0
# DB00211 Midodrine small molecule ['approved'] targets: 3 enzymes: 1 transporters: 1
# DB00212 Remikiren small molecule ['experimental'] targets: 1 enzymes: 0 transporters: 0
# DB00213 Pantoprazole small molecule ['approved'] targets: 2 enzymes: 2 transporters: 3
# DB00214 Torasemide small molecule ['approved'] targets: 2 enzymes: 2 transporters: 1
# DB00215 Citalopram small molecule ['approved'] targets: 2 enzymes: 4 transporters: 1
# DB00216 Eletriptan small molecule ['approved', 'investigational'] targets: 7 enzymes: 6 transporters: 1
# DB00217 Bethanidine small molecule ['approved'] targets: 3 enzymes: 0 transporters: 0
# DB00218 Moxifloxacin small molecule ['approved', 'investigational'] targets: 3 enzymes: 1 transporters: 0
# DB00219 Oxyphenonium small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00220 Nelfinavir small molecule ['approved'] targets: 1 enzymes: 8 transporters: 8
# DB00221 Isoetharine small molecule ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00222 Glimepiride small molecule ['approved'] targets: 3 enzymes: 1 transporters: 1
# DB00223 Diflorasone small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00224 Indinavir small molecule ['approved'] targets: 1 enzymes: 5 transporters: 8
# DB00225 Gadodiamide small molecule ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00226 Guanadrel small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00227 Lovastatin small molecule ['approved', 'investigational'] targets: 3 enzymes: 7 transporters: 7
# DB00228 Enflurane small molecule ['approved', 'investigational', 'vet_approved'] targets: 7 enzymes: 1 transporters: 0
# DB00229 Cefotiam small molecule ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 2
# DB00230 Pregabalin small molecule ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 2
# DB00231 Temazepam small molecule ['approved', 'investigational'] targets: 21 enzymes: 3 transporters: 0
# DB00232 Methyclothiazide small molecule ['approved'] targets: 4 enzymes: 0 transporters: 0
# DB00233 Aminosalicylic acid small molecule ['approved'] targets: 5 enzymes: 1 transporters: 0
# DB00234 Reboxetine small molecule ['approved', 'experimental'] targets: 1 enzymes: 2 transporters: 1
# DB00235 Milrinone small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00236 Pipobroman small molecule ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00237 Butabarbital small molecule ['approved', 'illicit'] targets: 5 enzymes: 0 transporters: 0
# DB00238 Nevirapine small molecule ['approved'] targets: 1 enzymes: 8 transporters: 1
# DB00239 Oxiconazole small molecule ['approved'] targets: 3 enzymes: 2 transporters: 0
# DB00240 Alclometasone small molecule ['approved'] targets: 1 enzymes: 1 transporters: 0
# DB00241 Butalbital small molecule ['approved', 'illicit'] targets: 11 enzymes: 0 transporters: 0
# DB00242 Cladribine small molecule ['approved', 'investigational'] targets: 9 enzymes: 1 transporters: 2
# DB00243 Ranolazine small molecule ['approved', 'investigational'] targets: 5 enzymes: 2 transporters: 2
# DB00244 Mesalazine small molecule ['approved'] targets: 8 enzymes: 1 transporters: 0
# DB00245 Benzatropine small molecule ['approved'] targets: 5 enzymes: 0 transporters: 0
# DB00246 Ziprasidone small molecule ['approved'] targets: 25 enzymes: 2 transporters: 0
# DB00247 Methysergide small molecule ['approved'] targets: 8 enzymes: 1 transporters: 0
# DB00248 Cabergoline small molecule ['approved'] targets: 21 enzymes: 1 transporters: 1
# DB00249 Idoxuridine small molecule ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00250 Dapsone small molecule ['approved', 'investigational'] targets: 2 enzymes: 13 transporters: 0
# DB00251 Terconazole small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00252 Phenytoin small molecule ['approved', 'vet_approved'] targets: 10 enzymes: 20 transporters: 3
# DB00253 Medrysone small molecule ['approved'] targets: 1 enzymes: 2 transporters: 0
# DB00254 Doxycycline small molecule ['approved', 'investigational', 'vet_approved'] targets: 0 enzymes: 1 transporters: 2
# DB00255 Diethylstilbestrol small molecule ['approved', 'investigational'] targets: 9 enzymes: 6 transporters: 5
# DB00256 Lymecycline small molecule ['approved', 'investigational'] targets: 2 enzymes: 0 transporters: 0
# DB00257 Clotrimazole small molecule ['approved', 'vet_approved'] targets: 4 enzymes: 8 transporters: 4
# DB00258 Calcium acetate small molecule ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00259 Sulfanilamide small molecule ['approved'] targets: 1 enzymes: 4 transporters: 0
# DB00260 Cycloserine small molecule ['approved'] targets: 2 enzymes: 1 transporters: 1
# DB00261 Anagrelide small molecule ['approved'] targets: 1 enzymes: 1 transporters: 0
# DB00262 Carmustine small molecule ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00263 Sulfisoxazole small molecule ['approved', 'vet_approved'] targets: 1 enzymes: 1 transporters: 0
# DB00264 Metoprolol small molecule ['approved', 'investigational'] targets: 2 enzymes: 2 transporters: 2
# DB00265 Crotamiton small molecule ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00266 Dicoumarol small molecule ['approved'] targets: 3 enzymes: 3 transporters: 0
# DB00267 Cefmenoxime small molecule ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00268 Ropinirole small molecule ['approved', 'investigational'] targets: 4 enzymes: 1 transporters: 0
# DB00269 Chlorotrianisene small molecule ['investigational', 'withdrawn'] targets: 1 enzymes: 1 transporters: 0
# DB00270 Isradipine small molecule ['approved', 'investigational'] targets: 7 enzymes: 1 transporters: 1
# DB00271 Diatrizoate small molecule ['approved', 'vet_approved'] targets: 0 enzymes: 0 transporters: 0
# DB00272 Betazole small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00273 Topiramate small molecule ['approved'] targets: 9 enzymes: 2 transporters: 2
# DB00274 Cefmetazole small molecule ['approved', 'investigational'] targets: 6 enzymes: 0 transporters: 2
# DB00275 Olmesartan small molecule ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 4
# DB00276 Amsacrine small molecule ['approved', 'investigational'] targets: 4 enzymes: 0 transporters: 1
# DB00277 Theophylline small molecule ['approved'] targets: 14 enzymes: 7 transporters: 1
# DB00278 Argatroban small molecule ['approved', 'investigational'] targets: 1 enzymes: 2 transporters: 0
# DB00279 Liothyronine small molecule ['approved', 'vet_approved'] targets: 3 enzymes: 1 transporters: 11
# DB00280 Disopyramide small molecule ['approved'] targets: 8 enzymes: 2 transporters: 2
# DB00281 Lidocaine small molecule ['approved', 'vet_approved'] targets: 7 enzymes: 9 transporters: 2
# DB00282 Pamidronic acid small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00283 Clemastine small molecule ['approved', 'investigational'] targets: 1 enzymes: 1 transporters: 0
# DB00284 Acarbose small molecule ['approved', 'investigational'] targets: 4 enzymes: 0 transporters: 0
# DB00285 Venlafaxine small molecule ['approved'] targets: 3 enzymes: 2 transporters: 2
# DB00286 Conjugated estrogens small molecule ['approved'] targets: 2 enzymes: 3 transporters: 21
# DB00287 Travoprost small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00288 Amcinonide small molecule ['approved'] targets: 2 enzymes: 2 transporters: 0
# DB00289 Atomoxetine small molecule ['approved'] targets: 5 enzymes: 2 transporters: 0
# DB00290 Bleomycin small molecule ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00291 Chlorambucil small molecule ['approved'] targets: 0 enzymes: 1 transporters: 1
# DB00292 Etomidate small molecule ['approved'] targets: 3 enzymes: 2 transporters: 0
# DB00293 Raltitrexed small molecule ['approved', 'investigational'] targets: 2 enzymes: 0 transporters: 0
# DB00294 Etonogestrel small molecule ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00295 Morphine small molecule ['approved', 'investigational'] targets: 4 enzymes: 8 transporters: 1
# DB00296 Ropivacaine small molecule ['approved'] targets: 1 enzymes: 3 transporters: 0
# DB00297 Bupivacaine small molecule ['approved', 'investigational'] targets: 2 enzymes: 3 transporters: 0
# DB00298 Dapiprazole small molecule ['approved'] targets: 3 enzymes: 0 transporters: 0
# DB00299 Penciclovir small molecule ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00300 Tenofovir disoproxil small molecule ['approved', 'investigational'] targets: 2 enzymes: 4 transporters: 6
# DB00301 Flucloxacillin small molecule ['approved', 'investigational'] targets: 1 enzymes: 1 transporters: 1
# DB00302 Tranexamic acid small molecule ['approved'] targets: 1 enzymes: 0 transporters: 1
# DB00303 Ertapenem small molecule ['approved', 'investigational'] targets: 8 enzymes: 0 transporters: 0
# DB00304 Desogestrel small molecule ['approved'] targets: 2 enzymes: 3 transporters: 0
# DB00305 Mitomycin small molecule ['approved'] targets: 0 enzymes: 1 transporters: 0
# DB00306 Talbutal small molecule ['approved', 'illicit'] targets: 11 enzymes: 0 transporters: 0
# DB00307 Bexarotene small molecule ['approved', 'investigational'] targets: 3 enzymes: 2 transporters: 0
# DB00308 Ibutilide small molecule ['approved'] targets: 10 enzymes: 0 transporters: 0
# DB00309 Vindesine small molecule ['approved', 'investigational'] targets: 1 enzymes: 1 transporters: 0
# DB00310 Chlorthalidone small molecule ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00311 Ethoxzolamide small molecule ['withdrawn'] targets: 5 enzymes: 0 transporters: 1
# DB00312 Pentobarbital small molecule ['approved', 'investigational', 'vet_approved'] targets: 13 enzymes: 3 transporters: 0
# DB00313 Valproic acid small molecule ['approved', 'investigational'] targets: 9 enzymes: 17 transporters: 6
# DB00314 Capreomycin small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00315 Zolmitriptan small molecule ['approved', 'investigational'] targets: 4 enzymes: 2 transporters: 0
# DB00316 Acetaminophen small molecule ['approved'] targets: 4 enzymes: 15 transporters: 1
# DB00317 Gefitinib small molecule ['approved', 'investigational'] targets: 1 enzymes: 6 transporters: 2
# DB00318 Codeine small molecule ['approved', 'illicit'] targets: 3 enzymes: 4 transporters: 1
# DB00319 Piperacillin small molecule ['approved'] targets: 4 enzymes: 0 transporters: 2
# DB00320 Dihydroergotamine small molecule ['approved', 'investigational'] targets: 4 enzymes: 1 transporters: 1
# DB00321 Amitriptyline small molecule ['approved'] targets: 28 enzymes: 10 transporters: 1
# DB00322 Floxuridine small molecule ['approved'] targets: 1 enzymes: 2 transporters: 0
# DB00323 Tolcapone small molecule ['approved', 'withdrawn'] targets: 1 enzymes: 1 transporters: 0
# DB00324 Fluorometholone small molecule ['approved', 'investigational'] targets: 1 enzymes: 2 transporters: 0
# DB00325 Nitroprusside small molecule ['approved', 'investigational'] targets: 1 enzymes: 1 transporters: 0
# DB00326 Calcium glucoheptonate small molecule ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00327 Hydromorphone small molecule ['approved', 'illicit'] targets: 3 enzymes: 3 transporters: 0
# DB00328 Indomethacin small molecule ['approved', 'investigational'] targets: 9 enzymes: 6 transporters: 15
# DB00330 Ethambutol small molecule ['approved'] targets: 3 enzymes: 0 transporters: 0
# DB00331 Metformin small molecule ['approved'] targets: 3 enzymes: 0 transporters: 6
# DB00332 Ipratropium small molecule ['approved', 'experimental'] targets: 3 enzymes: 0 transporters: 2
# DB00333 Methadone small molecule ['approved'] targets: 8 enzymes: 10 transporters: 1
# DB00334 Olanzapine small molecule ['approved', 'investigational'] targets: 20 enzymes: 8 transporters: 1
# DB00335 Atenolol small molecule ['approved'] targets: 2 enzymes: 1 transporters: 1
# DB00336 Nitrofural small molecule ['approved', 'investigational', 'vet_approved'] targets: 4 enzymes: 1 transporters: 0
# DB00337 Pimecrolimus small molecule ['approved', 'investigational'] targets: 2 enzymes: 1 transporters: 0
# DB00338 Omeprazole small molecule ['approved', 'investigational', 'vet_approved'] targets: 2 enzymes: 9 transporters: 3
# DB00339 Pyrazinamide small molecule ['approved', 'investigational'] targets: 1 enzymes: 2 transporters: 0
# DB00340 Metixene small molecule ['approved'] targets: 5 enzymes: 0 transporters: 0
# DB00341 Cetirizine small molecule ['approved'] targets: 1 enzymes: 0 transporters: 1
# DB00342 Terfenadine small molecule ['approved', 'withdrawn'] targets: 7 enzymes: 6 transporters: 2
# DB00343 Diltiazem small molecule ['approved', 'investigational'] targets: 2 enzymes: 6 transporters: 1
# DB00344 Protriptyline small molecule ['approved'] targets: 2 enzymes: 0 transporters: 1
# DB00345 Aminohippuric acid small molecule ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 13
# DB00346 Alfuzosin small molecule ['approved', 'investigational'] targets: 4 enzymes: 1 transporters: 0
# DB00347 Trimethadione small molecule ['approved'] targets: 1 enzymes: 5 transporters: 0
# DB00348 Nitisinone small molecule ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00349 Clobazam small molecule ['approved', 'illicit'] targets: 1 enzymes: 5 transporters: 3
# DB00350 Minoxidil small molecule ['approved', 'investigational'] targets: 3 enzymes: 1 transporters: 0
# DB00351 Megestrol acetate small molecule ['approved', 'investigational', 'vet_approved'] targets: 2 enzymes: 1 transporters: 1
# DB00352 Tioguanine small molecule ['approved'] targets: 0 enzymes: 1 transporters: 1
# DB00353 Methylergometrine small molecule ['approved'] targets: 2 enzymes: 1 transporters: 0
# DB00354 Buclizine small molecule ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00355 Aztreonam small molecule ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00356 Chlorzoxazone small molecule ['approved'] targets: 1 enzymes: 6 transporters: 0
# DB00357 Aminoglutethimide small molecule ['approved', 'investigational'] targets: 2 enzymes: 2 transporters: 0
# DB00358 Mefloquine small molecule ['approved', 'investigational'] targets: 2 enzymes: 4 transporters: 1
# DB00359 Sulfadiazine small molecule ['approved', 'investigational', 'vet_approved'] targets: 0 enzymes: 3 transporters: 0
# DB00360 Sapropterin small molecule ['approved', 'investigational'] targets: 4 enzymes: 1 transporters: 0
# DB00361 Vinorelbine small molecule ['approved', 'investigational'] targets: 1 enzymes: 2 transporters: 1
# DB00362 Anidulafungin small molecule ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00363 Clozapine small molecule ['approved'] targets: 27 enzymes: 10 transporters: 1
# DB00364 Sucralfate small molecule ['approved'] targets: 4 enzymes: 0 transporters: 0
# DB00365 Grepafloxacin small molecule ['approved', 'investigational', 'withdrawn'] targets: 2 enzymes: 2 transporters: 6
# DB00366 Doxylamine small molecule ['approved', 'vet_approved'] targets: 3 enzymes: 1 transporters: 0
# DB00367 Levonorgestrel small molecule ['approved', 'investigational'] targets: 6 enzymes: 2 transporters: 0
# DB00368 Norepinephrine small molecule ['approved'] targets: 12 enzymes: 0 transporters: 6
# DB00369 Cidofovir small molecule ['approved'] targets: 1 enzymes: 1 transporters: 1
# DB00370 Mirtazapine small molecule ['approved'] targets: 6 enzymes: 3 transporters: 1
# DB00371 Meprobamate small molecule ['approved', 'illicit'] targets: 7 enzymes: 0 transporters: 0
# DB00372 Thiethylperazine small molecule ['approved', 'withdrawn'] targets: 3 enzymes: 0 transporters: 0
# DB00373 Timolol small molecule ['approved'] targets: 3 enzymes: 2 transporters: 1
# DB00374 Treprostinil small molecule ['approved', 'investigational'] targets: 3 enzymes: 1 transporters: 0
# DB00375 Colestipol small molecule ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00376 Trihexyphenidyl small molecule ['approved'] targets: 5 enzymes: 0 transporters: 0
# DB00377 Palonosetron small molecule ['approved', 'investigational'] targets: 1 enzymes: 3 transporters: 0
# DB00378 Dydrogesterone small molecule ['approved', 'investigational', 'withdrawn'] targets: 1 enzymes: 1 transporters: 0
# DB00379 Mexiletine small molecule ['approved', 'investigational'] targets: 2 enzymes: 5 transporters: 0
# DB00380 Dexrazoxane small molecule ['approved', 'withdrawn'] targets: 2 enzymes: 0 transporters: 0
# DB00381 Amlodipine small molecule ['approved'] targets: 8 enzymes: 6 transporters: 1
# DB00382 Tacrine small molecule ['approved', 'investigational', 'withdrawn'] targets: 3 enzymes: 1 transporters: 1
# DB00383 Oxyphencyclimine small molecule ['approved'] targets: 3 enzymes: 0 transporters: 0
# DB00384 Triamterene small molecule ['approved'] targets: 4 enzymes: 1 transporters: 0
# DB00385 Valrubicin small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00387 Procyclidine small molecule ['approved'] targets: 4 enzymes: 0 transporters: 0
# DB00388 Phenylephrine small molecule ['approved'] targets: 3 enzymes: 4 transporters: 0
# DB00389 Carbimazole small molecule ['approved', 'investigational'] targets: 1 enzymes: 1 transporters: 0
# DB00390 Digoxin small molecule ['approved'] targets: 1 enzymes: 1 transporters: 7
# DB00391 Sulpiride small molecule ['approved', 'investigational'] targets: 4 enzymes: 1 transporters: 0
# DB00392 Profenamine small molecule ['approved'] targets: 3 enzymes: 1 transporters: 0
# DB00393 Nimodipine small molecule ['approved', 'investigational'] targets: 10 enzymes: 1 transporters: 0
# DB00394 Beclomethasone dipropionate small molecule ['approved', 'investigational'] targets: 1 enzymes: 2 transporters: 4
# DB00395 Carisoprodol small molecule ['approved'] targets: 5 enzymes: 1 transporters: 0
# DB00396 Progesterone small molecule ['approved', 'vet_approved'] targets: 10 enzymes: 10 transporters: 10
# DB00397 Phenylpropanolamine small molecule ['approved', 'vet_approved', 'withdrawn'] targets: 4 enzymes: 1 transporters: 0
# DB00398 Sorafenib small molecule ['approved', 'investigational'] targets: 10 enzymes: 11 transporters: 6
# DB00399 Zoledronic acid small molecule ['approved'] targets: 2 enzymes: 0 transporters: 1
# DB00400 Griseofulvin small molecule ['approved', 'investigational', 'vet_approved'] targets: 3 enzymes: 2 transporters: 0
# DB00401 Nisoldipine small molecule ['approved'] targets: 5 enzymes: 3 transporters: 1
# DB00402 Eszopiclone small molecule ['approved', 'investigational'] targets: 5 enzymes: 2 transporters: 0
# DB00403 Ceruletide small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00404 Alprazolam small molecule ['approved', 'illicit', 'investigational'] targets: 8 enzymes: 4 transporters: 0
# DB00405 Dexbrompheniramine small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00406 Gentian violet cation small molecule ['approved'] targets: 0 enzymes: 0 transporters: 1
# DB00407 Ardeparin small molecule ['approved', 'investigational', 'withdrawn'] targets: 2 enzymes: 0 transporters: 0
# DB00408 Loxapine small molecule ['approved'] targets: 33 enzymes: 0 transporters: 0
# DB00409 Remoxipride small molecule ['approved', 'withdrawn'] targets: 5 enzymes: 1 transporters: 0
# DB00410 Mupirocin small molecule ['approved', 'investigational', 'vet_approved'] targets: 1 enzymes: 0 transporters: 0
# DB00411 Carbamoylcholine small molecule ['approved'] targets: 6 enzymes: 1 transporters: 0
# DB00412 Rosiglitazone small molecule ['approved', 'investigational'] targets: 7 enzymes: 7 transporters: 2
# DB00413 Pramipexole small molecule ['approved', 'investigational'] targets: 5 enzymes: 0 transporters: 3
# DB00414 Acetohexamide small molecule ['approved', 'investigational', 'withdrawn'] targets: 1 enzymes: 2 transporters: 0
# DB00415 Ampicillin small molecule ['approved', 'vet_approved'] targets: 8 enzymes: 0 transporters: 4
# DB00416 Metocurine iodide small molecule ['approved', 'withdrawn'] targets: 1 enzymes: 0 transporters: 0
# DB00417 Phenoxymethylpenicillin small molecule ['approved', 'vet_approved'] targets: 4 enzymes: 0 transporters: 0
# DB00418 Secobarbital small molecule ['approved', 'vet_approved'] targets: 11 enzymes: 4 transporters: 0
# DB00419 Miglustat small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00420 Promazine small molecule ['approved', 'vet_approved'] targets: 14 enzymes: 5 transporters: 0
# DB00421 Spironolactone small molecule ['approved'] targets: 10 enzymes: 2 transporters: 4
# DB00422 Methylphenidate small molecule ['approved', 'investigational'] targets: 3 enzymes: 1 transporters: 0
# DB00423 Methocarbamol small molecule ['approved', 'vet_approved'] targets: 1 enzymes: 0 transporters: 0
# DB00424 Hyoscyamine small molecule ['approved'] targets: 4 enzymes: 0 transporters: 0
# DB00425 Zolpidem small molecule ['approved'] targets: 4 enzymes: 5 transporters: 0
# DB00426 Famciclovir small molecule ['approved', 'investigational'] targets: 0 enzymes: 1 transporters: 0
# DB00427 Triprolidine small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00428 Streptozocin small molecule ['approved', 'investigational'] targets: 2 enzymes: 3 transporters: 1
# DB00429 Carboprost tromethamine small molecule ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB00430 Cefpiramide small molecule ['approved'] targets: 7 enzymes: 0 transporters: 0
# DB00431 Lindane small molecule ['approved', 'withdrawn'] targets: 10 enzymes: 0 transporters: 0
# DB00432 Trifluridine small molecule ['approved', 'investigational'] targets: 1 enzymes: 2 transporters: 4
# DB00433 Prochlorperazine small molecule ['approved', 'vet_approved'] targets: 4 enzymes: 1 transporters: 0
# DB00434 Cyproheptadine small molecule ['approved'] targets: 7 enzymes: 1 transporters: 0
# DB00435 Nitric Oxide small molecule ['approved'] targets: 3 enzymes: 4 transporters: 0
# DB00436 Bendroflumethiazide small molecule ['approved'] targets: 5 enzymes: 1 transporters: 0
# DB00437 Allopurinol small molecule ['approved'] targets: 1 enzymes: 2 transporters: 4
# DB00438 Ceftazidime small molecule ['approved'] targets: 9 enzymes: 0 transporters: 4
# DB00439 Cerivastatin small molecule ['approved', 'withdrawn'] targets: 1 enzymes: 8 transporters: 5
# DB00440 Trimethoprim small molecule ['approved', 'vet_approved'] targets: 2 enzymes: 3 transporters: 2
# DB00441 Gemcitabine small molecule ['approved'] targets: 3 enzymes: 2 transporters: 6
# DB00442 Entecavir small molecule ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00443 Betamethasone small molecule ['approved', 'vet_approved'] targets: 1 enzymes: 3 transporters: 1
# DB00444 Teniposide small molecule ['approved'] targets: 1 enzymes: 4 transporters: 2
# DB00445 Epirubicin small molecule ['approved'] targets: 2 enzymes: 2 transporters: 1
# DB00446 Chloramphenicol small molecule ['approved', 'vet_approved'] targets: 3 enzymes: 6 transporters: 1
# DB00447 Loracarbef small molecule ['approved', 'investigational', 'withdrawn'] targets: 2 enzymes: 0 transporters: 2
# DB00448 Lansoprazole small molecule ['approved', 'investigational'] targets: 2 enzymes: 8 transporters: 6
# DB00449 Dipivefrin small molecule ['approved'] targets: 5 enzymes: 0 transporters: 0
# DB00450 Droperidol small molecule ['approved', 'vet_approved'] targets: 2 enzymes: 0 transporters: 0
# DB00451 Levothyroxine small molecule ['approved'] targets: 4 enzymes: 3 transporters: 10
# DB00452 Framycetin small molecule ['approved'] targets: 2 enzymes: 0 transporters: 0
# DB00453 Clomocycline small molecule ['experimental'] targets: 2 enzymes: 0 transporters: 0
# DB00454 Meperidine small molecule ['approved'] targets: 12 enzymes: 5 transporters: 0
# DB00455 Loratadine small molecule ['approved', 'investigational'] targets: 2 enzymes: 13 transporters: 2
# DB00456 Cefalotin small molecule ['approved', 'investigational', 'vet_approved'] targets: 7 enzymes: 0 transporters: 7
# DB00457 Prazosin small molecule ['approved'] targets: 7 enzymes: 0 transporters: 4
# DB00458 Imipramine small molecule ['approved'] targets: 24 enzymes: 8 transporters: 4
# DB00459 Acitretin small molecule ['approved'] targets: 7 enzymes: 0 transporters: 0
# DB00460 Verteporfin small molecule ['approved', 'investigational'] targets: 0 enzymes: 0 transporters: 0
# DB00461 Nabumetone small molecule ['approved'] targets: 2 enzymes: 7 transporters: 0
# DB00462 Methscopolamine bromide small molecule ['approved'] targets: 3 enzymes: 0 transporters: 0
# DB00463 Metharbital small molecule ['withdrawn'] targets: 11 enzymes: 0 transporters: 0
# DB00464 Sodium tetradecyl sulfate small molecule ['approved', 'investigational'] targets: 2 enzymes: 0 transporters: 0
# DB00465 Ketorolac small molecule ['approved'] targets: 2 enzymes: 3 transporters: 0
# DB00466 Picrotoxin small molecule ['experimental'] targets: 5 enzymes: 2 transporters: 0
# DB00467 Enoxacin small molecule ['approved', 'investigational'] targets: 3 enzymes: 1 transporters: 0
# DB00468 Quinine small molecule ['approved'] targets: 2 enzymes: 10 transporters: 7
# DB00469 Tenoxicam small molecule ['approved'] targets: 2 enzymes: 1 transporters: 1
# DB00470 Dronabinol small molecule ['approved', 'illicit'] targets: 2 enzymes: 3 transporters: 2
# DB00471 Montelukast small molecule ['approved'] targets: 2 enzymes: 5 transporters: 1
# DB00472 Fluoxetine small molecule ['approved', 'vet_approved'] targets: 7 enzymes: 8 transporters: 1
# DB00473 Hexylcaine small molecule ['approved', 'withdrawn'] targets: 2 enzymes: 0 transporters: 0
# DB00474 Methohexital small molecule ['approved'] targets: 1 enzymes: 1 transporters: 0
# DB00475 Chlordiazepoxide small molecule ['approved', 'illicit', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00476 Duloxetine small molecule ['approved'] targets: 3 enzymes: 3 transporters: 1
# DB00477 Chlorpromazine small molecule ['approved', 'investigational', 'vet_approved'] targets: 24 enzymes: 5 transporters: 2
# DB00478 Rimantadine small molecule ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00479 Amikacin small molecule ['approved', 'investigational', 'vet_approved'] targets: 1 enzymes: 0 transporters: 0
# DB00480 Lenalidomide small molecule ['approved'] targets: 4 enzymes: 0 transporters: 1
# DB00481 Raloxifene small molecule ['approved', 'investigational'] targets: 4 enzymes: 8 transporters: 7
# DB00482 Celecoxib small molecule ['approved', 'investigational'] targets: 5 enzymes: 4 transporters: 4
# DB00483 Gallamine triethiodide small molecule ['approved'] targets: 5 enzymes: 0 transporters: 0
# DB00484 Brimonidine small molecule ['approved'] targets: 3 enzymes: 1 transporters: 0
# DB00485 Dicloxacillin small molecule ['approved', 'investigational', 'vet_approved'] targets: 6 enzymes: 1 transporters: 2
# DB00486 Nabilone small molecule ['approved', 'investigational'] targets: 2 enzymes: 3 transporters: 0
# DB00487 Pefloxacin small molecule ['approved'] targets: 4 enzymes: 1 transporters: 0
# DB00488 Altretamine small molecule ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB00489 Sotalol small molecule ['approved'] targets: 3 enzymes: 1 transporters: 0
# DB00490 Buspirone small molecule ['approved', 'investigational'] targets: 5 enzymes: 4 transporters: 1
# DB00491 Miglitol small molecule ['approved'] targets: 4 enzymes: 1 transporters: 0
# DB00492 Fosinopril small molecule ['approved'] targets: 1 enzymes: 0 transporters: 2
# DB00493 Cefotaxime small molecule ['approved'] targets: 12 enzymes: 0 transporters: 6
# DB00494 Entacapone small molecule ['approved', 'investigational'] targets: 1 enzymes: 3 transporters: 0
# DB00495 Zidovudine small molecule ['approved'] targets: 2 enzymes: 6 transporters: 11
# DB00496 Darifenacin small molecule ['approved', 'investigational'] targets: 5 enzymes: 2 transporters: 0
# DB00497 Oxycodone small molecule ['approved', 'illicit', 'investigational'] targets: 3 enzymes: 3 transporters: 0
# DB00498 Phenindione small molecule ['approved', 'investigational'] targets: 1 enzymes: 0 transporters: 0
# DB00499 Flutamide small molecule ['approved', 'investigational'] targets: 3 enzymes: 6 transporters: 0
# ...
# DB15440 GSK-3117391 small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15441 Lulizumab pegol biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15442 Trilaciclib small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15443 Lorukafusp alfa biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15444 Elexacaftor small molecule ['approved', 'investigational'] targets: 1 enzymes: 8 transporters: 3
# DB15445 Iodohippuric acid small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15446 Vidofludimus small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15447 Setogepram small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15448 Acumapimod small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15449 Citarinostat small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15450 PF-05105679 small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15451 SOBI-003 biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15452 Technetium Tc-99m epratuzumab biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15453 Naratuximab emtansine biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15455 Cenersen biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15456 Vericiguat small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15457 Snubh-nm-333 F-18 small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15458 Norleucine small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15460 AGG-523 small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15461 Yersinia pestis 195/p antigen (formaldehyde inactivated) biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15462 Fucoxanthin small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15463 PT2977 small molecule ['investigational'] targets: 1 enzymes: 0 transporters: 0
# DB15464 Urolithin A small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15465 Benzhydrocodone small molecule ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15466 Tallimustine small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15467 Cinoxate small molecule ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15468 Iscotrizinol small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15469 Octyl triazone small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15470 Minretumomab biotech ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15471 ZW-25 biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15472 ZW-49 biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15473 Haemagglutinin-strain B (Victoria) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15474 Haemagglutinin-strain B (Yamagata) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15475 Haemagglutinin-strain A(H3N2) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15476 Haemagglutinin-strain A(H1N1) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15477 Alloin small molecule ['approved', 'experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15478 Frangula purshiana bark biotech ['approved', 'experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15479 Zirconium chloride hydroxide small molecule ['approved', 'experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15480 Resorcinol monoacetate small molecule ['approved', 'experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15481 Fish liver oil biotech ['approved', 'experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15482 Haemagglutinin-strain B biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15483 Modified vaccinia ankara biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15484 VIBRIO CHOLERAE INABA 6973 E1 TOR BIOTYPE, FORMALIN INACTIVATED biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15485 VIBRIO CHOLERAE INABA 48 CLASSICAL BIOTYPE, HEAT INACTIVATED biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15486 VIBRIO CHOLERAE OGAWA 50 CLASSICAL BIOTYPE, HEAT INACTIVATED biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15487 VIBRIO CHOLERAE OGAWA 50 CLASSICAL BIOTYPE, FORMALIN INACTIVATED biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15488 Echinacoside small molecule ['experimental'] targets: 2 enzymes: 1 transporters: 0
# DB15489 Mexazolam small molecule ['experimental'] targets: 1 enzymes: 1 transporters: 0
# DB15490 Zuranolone small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15491 Oxazolam small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15492 Eticlopride small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15493 Cambinol small molecule ['experimental'] targets: 3 enzymes: 0 transporters: 0
# DB15494 Edotreotide gallium Ga-68 small molecule ['approved'] targets: 4 enzymes: 0 transporters: 0
# DB15495 Rocaglamide small molecule ['experimental'] targets: 2 enzymes: 0 transporters: 0
# DB15496 Didesmethylrocaglamide small molecule ['experimental'] targets: 2 enzymes: 0 transporters: 0
# DB15497 Smallpox and Monkeypox Vaccine, Live, Non-replicating biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15498 BOS172722 small molecule ['experimental'] targets: 1 enzymes: 0 transporters: 0
# DB15499 Cerdulatinib small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15500 Influenza A virus A/Brisbane/02/2018 IVR-190 (H1N1) antigen (propiolactone inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15501 Influenza A virus A/Kansas/14/2017 X-327 (H3N2) antigen (propiolactone inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15502 Baccharis sarothroides whole biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15503 Amaranthus hybridus pollen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15504 Acacia dealbata pollen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15505 Influenza A virus A/Idaho/07/2018 (H1N1) antigen (MDCK cell derived, propiolactone inactivated biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15506 Influenza A virus A/Indiana/08/2018 (H3N2) antigen (MDCK cell derived, propiolactone inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15507 Influenza B virus B/Singapore/INFTT-16-0610/2016 antigen (MDCK cell derived, propiolactone inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15508 Influenza B virus B/Iowa/06/2017 antigen (MDCK cell derived, propiolactone inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15509 Alnus serrulata pollen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15510 Prosopis velutina seed biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15511 Gibberella fujikuroi biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15512 Mucor circinelloides f. circinelloides biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15513 Influenza A virus A/Switzerland/3330/2017 (H1N1) live (attenuated) antigen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15514 Influenza A virus A/Kansas/14/2017 (H3N2) live (attenuated) antigen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15515 Influenza A virus A/Brisbane/02/2018 IVR-190 (H1N1) antigen (formaldehyde inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15516 Influenza A virus A/Kansas/14/2017 X-327 (H3N2) antigen (formaldehyde inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15517 Influenza A virus A/Brisbane/02/2018 (H1N1) recombinant hemagglutinin antigen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15518 Influenza A virus A/Kansas/14/2017 (H3N2) recombinant hemagglutinin antigen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15519 Influenza A virus A/Brisbane/02/2018 IVR-190 (H1N1) antigen (UV, formaldehyde inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15520 Influenza A virus A/Kansas/14/2017 X-327 (H3N2) antigen (UV, formaldehyde inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15521 Cyd dengue virus serotype 1 live (attenuated) antigen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15522 Cyd dengue virus serotype 2 live (attenuated) antigen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15523 Cyd dengue virus serotype 3 live (attenuated) antigen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15524 Cyd dengue virus serotype 4 live (attenuated) antigen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15525 Mucor circinelloides f. lusitanicus biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15526 Eurotium amstelodami biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15527 Umirolimus small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15528 Onasemnogene abeparvovec biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15529 Leucanthemum vulgare pollen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15530 Trifolium pratense pollen biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15531 Silk sericin biotech ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15532 Madecassoside small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15533 Calcium sulfate small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15534 Colchiceine small molecule ['approved', 'experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15535 Cuprous chloride small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15536 Ferric chloride small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15537 Eucalyptus gum biotech ['approved', 'experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15538 Sea scallop biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15539 Northern brown shrimp biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15540 Rainbow trout biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15541 Yellowfin tuna biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15542 Atlantic mackerel biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15543 Pacific ocean perch biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15544 Myristica fragrans fruit biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15545 Pisum sativum whole biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15546 Skim milk biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15547 Black sea bass biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15548 Channel catfish biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15549 Atlantic halibut biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15550 Pradefovir small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15551 Leptazoline A small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15552 Leptazoline B small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15553 Leptazoline C small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15554 Leptazoline D small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15555 Magnesium malate small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15556 Zinc glycinate citrate small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15557 24-Homo-1,25-dihydroxyvitamin D3 small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15558 Imalumab biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15559 Zenocutuzumab biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15560 Reloxaliase biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15561 Valoctocogene roxaparvovec biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15562 Influenza A virus A/North carolina/04/2016 (H3N2) hemagglutinin antigen (MDCK cell derived, propiolactone inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15563 Influenza B virus B/Iowa/06/2017 hemagglutinin antigen (MDCK cell derived, propiolactone inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15564 Influenza B virus B/Singapore/INFTT-16-0610/2016 hemagglutinin antigen (MDCK cell derived, propiolactone inactivated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15565 Cilazaprilat small molecule ['experimental'] targets: 1 enzymes: 0 transporters: 0
# DB15566 Prednisolone acetate small molecule ['approved', 'vet_approved'] targets: 1 enzymes: 1 transporters: 2
# DB15567 PCLX-001 small molecule ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15568 MRTX849 small molecule ['investigational'] targets: 1 enzymes: 0 transporters: 0
# DB15569 AMG-510 small molecule ['investigational'] targets: 1 enzymes: 0 transporters: 0
# DB15570 FLX475 small molecule ['investigational'] targets: 1 enzymes: 0 transporters: 0
# DB15571 (12R)-12-hydroxyeicosapentaenoic acid small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15572 CTX001 biotech ['investigational'] targets: 0 enzymes: 0 transporters: 0
# DB15573 alpha-Pinene small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15574 beta-Pinene small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15575 Padeliporfin small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15576 Ethyl salicylate small molecule ['approved', 'experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15578 Desfesoterodine small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15579 Cryptotanshinone small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15580 Climbazole small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15581 Chrysin small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15582 Echinomycin small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15583 Fluazuron small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15584 Luteolin small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15585 ORG-31710 small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15586 Patulin small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15587 Antimony potassium tartrate small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15588 Ursolic acid small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15589 Zingerone small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15590 beta-Apopicropodophyllin small molecule ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15591 Atrial natriuretic peptide biotech ['experimental'] targets: 0 enzymes: 0 transporters: 0
# DB15592 Cucurbita pepo subsp. ovifera whole biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15593 Golodirsen biotech ['approved'] targets: 1 enzymes: 0 transporters: 0
# DB15594 Brilliant blue G small molecule ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15595 Ebola Zaire vaccine (live, attenuated) biotech ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15596 Aminopromazine small molecule ['experimental', 'vet_approved'] targets: 0 enzymes: 0 transporters: 0
# DB15597 Aminopentamide small molecule ['experimental', 'vet_approved'] targets: 0 enzymes: 0 transporters: 0
# DB15598 Ferric maltol small molecule ['approved'] targets: 0 enzymes: 0 transporters: 0
# DB15599 MIV-711 small molecule ['investigational'] targets: 1 enzymes: 0 transporters: 0

# %% [markdown]
# ## List of drugs to save (as long as num_targets + num_enzymes + num_transporters != 0)

# %%
drugs = []
for drugbank_id in sorted(drug2attrib.keys()):
    if len(drug2attrib[drugbank_id]['targets']) == 0 and len(drug2attrib[drugbank_id]['enzymes']) == 0 and len(drug2attrib[drugbank_id]['transporters']) == 0:
        continue
    else:
        drugs.append(drugbank_id)
        
print(len(drug2attrib), "drugs parsed from XML")
print(len(drugs), "drugs with at least 1 target/ enzyme/ transporter present")
# Out:
# 13475 drugs parsed from XML
# 7485 drugs with at least 1 target/ enzyme/ transporter present

# %% [markdown]
# ## Save drug attributes to CSV {'drugname', 'SMILES', 'drug_type', 'groups', 'targets/enzymes/transporters': [_id, _actions]}

# %%
outf = open('../Data/drugbank05_drugs.csv', 'w')
writer = csv.writer(outf)
writer.writerow(['drugbank_id', 'drugname', 'drug_type', 'approved', 'experimental', 'illicit', 'investigational', 'nutraceutical', 'withdrawn'])
    
for drugbank_id in drugs:
    drugname = drug2attrib[drugbank_id]['drugname']
    if isinstance(drugname, unicode):
        if u'\u03b2' in drugname:
            drugname = drugname.replace(u'\u03b2', 'beta')
        if u'\u03b1' in drugname:
            drugname = drugname.replace(u'\u03b1', 'alpha')
        drugname = drugname.encode("utf-8")
    drug_type = drug2attrib[drugbank_id]['drug_type']
    groups = [1 if group in drug2attrib[drugbank_id]['groups'] else 0 for group in ['approved', 'experimental', 'illicit', 'investigational', 'nutraceutical', 'withdrawn'] ]
    
    writer.writerow([drugbank_id, drugname, drug_type]+groups)
    
outf.close()

# %% [markdown]
# ## Save all targets, enzymes, transporters to CSV

# %%
# drugbank_target_id -> #{'gene', 'name', 'organism', 'taxonomy_id', 'uniprot_id', 'genbank_gene_id', 'genbank_protein_id', 'hgnc_id'}

outf = open('../Data/drugbank06_partner_protein.csv', 'w')
outfh = open('../Data/drugbank06_partner_protein_human.csv', 'w')
writer = csv.writer(outf)
writerh = csv.writer(outfh)

writer.writerow(['partner_id', 'partner_name', 'gene_name', 'uniprot_id', 'genbank_gene_id', 'genbank_protein_id', 'hgnc_id', 'organism', 'taxonomy_id'])
writerh.writerow(['partner_id', 'partner_name', 'gene_name', 'uniprot_id', 'genbank_gene_id', 'genbank_protein_id', 'hgnc_id', 'organism', 'taxonomy_id'])

partners_written = set()

# Targets
for partner_id in sorted(target2attrib.keys()):
    if partner_id in partners_written:
        # print partner_id, target2attrib[partner_id]['gene'], 'already recorded'
        continue
    
    partner_name = target2attrib[partner_id]['name']
    gene_name = target2attrib[partner_id]['gene']
    organism = target2attrib[partner_id]['organism']
    taxonomy_id = target2attrib[partner_id]['taxonomy_id']
    
    uniprot_id = target2attrib[partner_id]['uniprot_id']
    genbank_gene_id = target2attrib[partner_id]['genbank_gene_id']
    genbank_protein_id = target2attrib[partner_id]['genbank_protein_id']
    hgnc_id = target2attrib[partner_id]['hgnc_id']
    
    partners_written.add(partner_id)
    
    writer.writerow([partner_id, partner_name, gene_name, uniprot_id, genbank_gene_id, genbank_protein_id, hgnc_id, organism, taxonomy_id])
    
    if taxonomy_id == '9606' and (organism == 'Human' or 'human' in organism.lower()):
        writerh.writerow([partner_id, partner_name, gene_name, uniprot_id, genbank_gene_id, genbank_protein_id, hgnc_id, organism, taxonomy_id])
    
    if taxonomy_id == '9606' and 'human' not in organism.lower():
        print(partner_id, target2attrib[partner_id]['gene'], organism, taxonomy_id, 'organism mismatch')
        
        
# enzymes
for partner_id in sorted(enzyme2attrib.keys()):
    if partner_id in partners_written:
        # print partner_id, enzyme2attrib[partner_id]['gene'], 'already recorded in targets'
        continue
    
    partner_name = enzyme2attrib[partner_id]['name']
    gene_name = enzyme2attrib[partner_id]['gene']
    organism = enzyme2attrib[partner_id]['organism']
    taxonomy_id = enzyme2attrib[partner_id]['taxonomy_id']
    
    uniprot_id = enzyme2attrib[partner_id]['uniprot_id']
    genbank_gene_id = enzyme2attrib[partner_id]['genbank_gene_id']
    genbank_protein_id = enzyme2attrib[partner_id]['genbank_protein_id']
    hgnc_id = enzyme2attrib[partner_id]['hgnc_id']
    
    partners_written.add(partner_id)
    
    writer.writerow([partner_id, partner_name, gene_name, uniprot_id, genbank_gene_id, genbank_protein_id, hgnc_id, organism, taxonomy_id])
    
    if taxonomy_id == '9606' and (organism == 'Human' or 'human' in organism.lower()):
        writerh.writerow([partner_id, partner_name, gene_name, uniprot_id, genbank_gene_id, genbank_protein_id, hgnc_id, organism, taxonomy_id])
    
    if taxonomy_id == '9606' and 'human' not in organism.lower():
        print(partner_id, enzyme2attrib[partner_id]['gene'], organism, taxonomy_id, 'organism mismatch')
        
        
# transporters
for partner_id in sorted(transporter2attrib.keys()):
    if partner_id in partners_written:
        # print partner_id, transporter2attrib[partner_id]['gene'], 'already recorded in targets and/or enzymes'
        continue
    
    partner_name = transporter2attrib[partner_id]['name']
    gene_name = transporter2attrib[partner_id]['gene']
    organism = transporter2attrib[partner_id]['organism']
    taxonomy_id = transporter2attrib[partner_id]['taxonomy_id']
    
    uniprot_id = transporter2attrib[partner_id]['uniprot_id']
    genbank_gene_id = transporter2attrib[partner_id]['genbank_gene_id']
    genbank_protein_id = transporter2attrib[partner_id]['genbank_protein_id']
    hgnc_id = transporter2attrib[partner_id]['hgnc_id']
    
    partners_written.add(partner_id)
    
    writer.writerow([partner_id, partner_name, gene_name, uniprot_id, genbank_gene_id, genbank_protein_id, hgnc_id, organism, taxonomy_id])
    
    if taxonomy_id == '9606' and (organism == 'Human' or 'human' in organism.lower()):
        writerh.writerow([partner_id, partner_name, gene_name, uniprot_id, genbank_gene_id, genbank_protein_id, hgnc_id, organism, taxonomy_id])
    
    if taxonomy_id == '9606' and 'human' not in organism.lower():
        print(partner_id, transporter2attrib[partner_id]['gene'], organism, taxonomy_id, 'organism mismatch')
        
outf.close()
outfh.close()

# %% [markdown]
# ## Save drug-target, -enzyme, -transporter pairs to CSV

# %%
# target [('antagonist', 1374), ('agonist', 857), ('inhibitor', 1818)]
# enzyme [('substrate', 2402), ('inducer', 407), ('inhibitor', 1350)]
# transporter [('substrate', 790), ('inducer', 100), ('inhibitor', 1075)]

# Targets
outf = open('../Data/drugbank06_drug2target.csv', 'w')
outfh = open('../Data/drugbank06_drug2target_human.csv', 'w')
writer = csv.writer(outf)
writerh = csv.writer(outfh)

target_actions_to_write = ['inhibitor', 'antagonist', 'agonist']
writer.writerow(['drugbank_id', 'partner_id', 'gene_name']+target_actions_to_write)
writerh.writerow(['drugbank_id', 'partner_id', 'gene_name']+target_actions_to_write)

for drugbank_id in drugs:
    for (target_id, target_actions) in drug2attrib[drugbank_id]['targets']:
        actions = [1 if action in target_actions else 0 for action in target_actions_to_write]
        
        writer.writerow([drugbank_id, target_id, target2attrib[target_id]['gene']]+actions)
        
        if 'human' in target2attrib[target_id]['organism'].lower() and target2attrib[target_id]['taxonomy_id'] == '9606':
            writerh.writerow([drugbank_id, target_id, target2attrib[target_id]['gene']]+actions)

outf.close()
outfh.close()


# Enzymes
outf = open('../Data/drugbank06_drug2enzyme.csv', 'w')
outfh = open('../Data/drugbank06_drug2enzyme_human.csv', 'w')
writer = csv.writer(outf)
writerh = csv.writer(outfh)

enzyme_actions_to_write = ['substrate', 'inducer', 'inhibitor']
writer.writerow(['drugbank_id', 'partner_id', 'gene_name']+enzyme_actions_to_write)
writerh.writerow(['drugbank_id', 'partner_id', 'gene_name']+enzyme_actions_to_write)

for drugbank_id in drugs:
    for (enzyme_id, enzyme_actions) in drug2attrib[drugbank_id]['enzymes']:
        actions = [1 if action in enzyme_actions else 0 for action in enzyme_actions_to_write]
        
        writer.writerow([drugbank_id, enzyme_id, enzyme2attrib[enzyme_id]['gene']]+actions)
        
        if 'human' in enzyme2attrib[enzyme_id]['organism'].lower() and enzyme2attrib[enzyme_id]['taxonomy_id'] == '9606':
            writerh.writerow([drugbank_id, enzyme_id, enzyme2attrib[enzyme_id]['gene']]+actions)

outf.close()
outfh.close()


# Transporters
outf = open('../Data/drugbank06_drug2transporter.csv', 'w')
outfh = open('../Data/drugbank06_drug2transporter_human.csv', 'w')
writer = csv.writer(outf)
writerh = csv.writer(outfh)

transporter_actions_to_write = ['substrate', 'inducer', 'inhibitor']
writer.writerow(['drugbank_id', 'partner_id', 'gene_name']+transporter_actions_to_write)
writerh.writerow(['drugbank_id', 'partner_id', 'gene_name']+transporter_actions_to_write)

for drugbank_id in drugs:
    for (transporter_id, transporter_actions) in drug2attrib[drugbank_id]['transporters']:
        actions = [1 if action in transporter_actions else 0 for action in transporter_actions_to_write]
        
        writer.writerow([drugbank_id, transporter_id, transporter2attrib[transporter_id]['gene']]+actions)
        
        if 'human' in transporter2attrib[transporter_id]['organism'].lower() and transporter2attrib[transporter_id]['taxonomy_id'] == '9606':
            writerh.writerow([drugbank_id, transporter_id, transporter2attrib[transporter_id]['gene']]+actions)

outf.close()
outfh.close()
